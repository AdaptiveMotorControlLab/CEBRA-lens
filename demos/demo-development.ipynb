# %%
# !git clone https://eloisehabek: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@github.com/AdaptiveMotorControlLab/CEBRA-lens.git
# Out:
# Cloning into 'CEBRA-lens'...
# remote: Enumerating objects: 942, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 942 (delta 82), reused 72 (delta 30), pack-reused 718 (from 1)
# Receiving objects: 100% (942/942), 83.88 MiB | 13.04 MiB/s, done.
# Resolving deltas: 100% (450/450), done.

# %%
# !git clone -b eloise-def https://eloisehabek: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@github.com/AdaptiveMotorControlLab/CEBRA-lens.git
# Out:
# Cloning into 'CEBRA-lens'...
# remote: Enumerating objects: 952, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 952 (delta 91), reused 76 (delta 34), pack-reused 718 (from 1)
# Receiving objects: 100% (952/952), 83.88 MiB | 11.34 MiB/s, done.
# Resolving deltas: 100% (459/459), done.

# %%
# !git clone -b eloise-loader https://eloisehabek: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@github.com/AdaptiveMotorControlLab/CEBRA-lens.git
# Out:
# Cloning into 'CEBRA-lens'...
# remote: Enumerating objects: 958, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 958 (delta 96), reused 79 (delta 35), pack-reused 718 (from 1)
# Receiving objects: 100% (958/958), 83.88 MiB | 25.82 MiB/s, done.
# Resolving deltas: 100% (464/464), done.

# %%
# !pip install --pre 'cebra[datasets,demos]'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.0/205.0 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip freeze > requirements.txt

# %%
cd CEBRA-lens/
# Out:
# /content/CEBRA-lens

# %%
from cebra_lens.model import model_loader

# %%
import cebra_lens as lens

# %%
# !git pull origin eloise-def
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# Without labels

# %%
models = model_loader("/content/drive/MyDrive/mathis/FinalModels/VISION","offset10")
# Out:
# Number of models:  12
# ['allen_single_session_mouse4_10k_1_torch.pt', 'allen_single_session_mouse4_10k_2_torch.pt', 'allen_single_session_mouse4_10k_3_torch.pt', 'allen_single_session_mouse4_10k_4_torch.pt', 'allen_single_session_mouse4_0k_UT_torch.pt', 'allen_multi_session_0k_UT_torch.pt', 'allen_multi_session_10k_0_torch.pt', 'allen_multi_session_10k_1_torch.pt', 'allen_multi_session_10k_2_torch.pt', 'allen_multi_session_10k_3_torch.pt', 'allen_multi_session_10k_4_torch.pt', 'allen_single_session_mouse4_10k_0_torch.pt']
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# Loaded model
# # of Single Untrained models:  1
# # of Single Trained models:  5
# # of Multi Untrained models:  1
# # of Multi Trained models:  5

# %%
models
# Out:
# {'allen_single_session_mouse4_10k_1_torch': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
#  'allen_single_session_mouse4_10k_2_torch': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
#  'allen_single_session_mouse4_10k_3_torch': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
#  'allen_single_session_mouse4_10k_4_torch': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
# ...

# %% [markdown]
# With labels

# %%
labels = {'allen_single_session_mouse4_0k_UT_torch':'A',
          'allen_multi_session_10k_3_torch':'A',
          'allen_multi_session_10k_2_torch':'B',
          'allen_single_session_mouse4_10k_0_torch':'single_TR',
          'allen_single_session_mouse4_10k_1_torch':'B',
          'allen_multi_session_10k_4_torch':'C',
          'allen_multi_session_10k_0_torch':'multi_TR',
          'allen_multi_session_10k_1_torch':'multi_TR',
          'allen_single_session_mouse4_10k_3_torch':'single_TR',
          'allen_single_session_mouse4_10k_2_torch':'single_TR',
          'allen_multi_session_0k_UT_torch':'multi_UT',
          'allen_single_session_mouse4_10k_4_torch':'single_TR'}

# %%
model_labels = model_loader("/content/drive/MyDrive/mathis/FinalModels/VISION/offset10", labels=labels)
# Out:
# Model allen_single_session_mouse4_10k_1_torch loading...
# Model allen_single_session_mouse4_10k_1_torch loaded succesfully.
# Model allen_single_session_mouse4_10k_2_torch loading...
# Model allen_single_session_mouse4_10k_2_torch loaded succesfully.
# Model allen_single_session_mouse4_10k_3_torch loading...
# Model allen_single_session_mouse4_10k_3_torch loaded succesfully.
# Model allen_single_session_mouse4_10k_4_torch loading...
# Model allen_single_session_mouse4_10k_4_torch loaded succesfully.
# Model allen_single_session_mouse4_0k_UT_torch loading...
# Model allen_single_session_mouse4_0k_UT_torch loaded succesfully.
# Model allen_multi_session_0k_UT_torch loading...
# Model allen_multi_session_0k_UT_torch loaded succesfully.
# Model allen_multi_session_10k_0_torch loading...
# Model allen_multi_session_10k_0_torch loaded succesfully.
# Model allen_multi_session_10k_1_torch loading...
# Model allen_multi_session_10k_1_torch loaded succesfully.
# ...

# %%
model_labels
# Out:
# {'B': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True),
#   CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
#  'single_TR': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True),
#   CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True),
#   CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True),
# ...

# %%
cd /content/drive/MyDrive/mathis
# Out:
# /content/drive/MyDrive/mathis

# %%
# !ls
# Out:
# data  FinalModels  GithubFolder  inital.ipynb

# %%
session_id = 3
train_datas, valid_datas, discrete_labels_train, discrete_labels_val = (
    lens.utils_allen.get_single_session_datasets()
)
#this works fine

train_data = train_datas[session_id].neural
test_data = valid_datas[session_id].neural
train_label = discrete_labels_train[session_id]
test_label = discrete_labels_val[session_id]
# Out:
# /usr/local/lib/python3.11/dist-packages/cebra/datasets/allen/single_session_ca.py:246: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
results_dict = lens.quantification.decoding.decode_models(
    models=models,
    train_data=train_data,
    train_label=train_label,
    test_data=test_data,
    test_label=test_label,
    session_id=session_id,
)
print(results_dict.keys())
# Out:
# dict_keys(['B', 'single_TR', 'A', 'multi_UT', 'multi_TR', 'C'])

# %%
fig = lens.plotting.plot_decoding(results_dict=results_dict, palette="cool")

# %% [markdown]
# Part 3: B Model decoding by layer

# %%
models
# Out:
# {'single_UT': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu', max_iterations=1,
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
#  'multi_UT': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu', max_iterations=1,
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True)],
#  'single_TR': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True),
#   CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
#         time_offsets=10, verbose=True),
#   CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#         model_architecture='offset10-model', output_dimension=128, temperature=1,
# ...

# %%
dataset_label = "visual"
layer_type = "conv"
results_dict = lens.quantification.decoding.decode_by_layer_all(
        models_dict=model_labels,
        train_data=train_data,
        train_label=train_label,
        test_data=test_data,
        test_label=test_label,
        session_id=session_id,
        dataset_label=dataset_label,
        layer_type=layer_type,
    )
# Out:
# {'B': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#       model_architecture='offset10-model', output_dimension=128, temperature=1,
#       time_offsets=10, verbose=True), CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#       model_architecture='offset10-model', output_dimension=128, temperature=1,
#       time_offsets=10, verbose=True)], 'single_TR': [CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#       model_architecture='offset10-model', output_dimension=128, temperature=1,
#       time_offsets=10, verbose=True), CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#       model_architecture='offset10-model', output_dimension=128, temperature=1,
#       time_offsets=10, verbose=True), CEBRA(batch_size=2042, conditional='time_delta', device='cpu',
#       model_architecture='offset10-model', output_dimension=128, temperature=1,
# ...

# %%
results_dict
# Out:
# {'B': [array([[ 0.45624099, 25.        , 54.55555556],
#          [ 0.68709171, 20.        , 64.22222222],
#          [ 0.85593824, 16.        , 70.11111111],
#          [ 0.83802905, 14.        , 73.44444444],
#          [ 0.803419  , 12.        , 78.33333333],
#          [ 0.87267314, 12.        , 79.44444444],
#          [ 0.87267314, 12.        , 79.44444444]]),
#   array([[ 0.45624099, 25.        , 54.55555556],
#          [ 0.4840352 , 21.        , 60.33333333],
#          [ 0.80720297, 18.        , 65.        ],
#          [ 0.86059882, 15.        , 71.22222222],
#          [ 0.8986897 , 13.        , 72.33333333],
#          [ 0.88216958, 12.        , 75.        ],
#          [ 0.88216958, 12.        , 75.        ]])],
#  'single_TR': [array([[ 0.45624099, 25.        , 54.55555556],
#          [ 0.59756913, 21.        , 59.66666667],
#          [ 0.76053403, 14.        , 75.55555556],
#          [ 0.70694731, 13.        , 78.33333333],
# ...

# %%
fig = lens.plotting.plot_layer_decoding(results_dict=results_dict)
